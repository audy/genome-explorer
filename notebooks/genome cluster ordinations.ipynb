# %%
import cPickle
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

import pylab

import matplotlib.pyplot as plt

# use seaborn plotting defaults
# If this causes an error, you can comment it out.
import seaborn as sns
sns.set()

# %%
# load data

with open('genomes-cluster-matrix.pickle') as handle:
    df = cPickle.load(handle)
species = [ i.split()[1] for i in df.index ]

# %%
fitted = PCA().fit_transform(df.values)
species
# Out:
# [u'dorei',
#  u'dorei',
#  u'dorei',
#  u'vulgatus',
#  u'vulgatus',
#  u'vulgatus',
#  u'fragilis']

# %%
plt.scatter(fitted[:,0], fitted[:,1], c = [1,1,1,2,2,2,3], cmap=pylab.cm.cool)
plt.axis('equal')
plt.show()
