# %% [markdown]
# # generate cluster contigency table from uclust output
#
# before running do:
#
# ```sh
# rake dump:proteins > proteins.fasta
# rake dump:genomes > genomes.csv
# rake dump:features > features.csv
#
# sh cluster_usearch.sh
# ```
#
# Then run this notebook to generate the table as `genome-cluster-table.csv`.
#
# Cluster #s are assigned arbitrarily and are subject to change every time you run `cluster_usearch.sh`
#
# ## TODO
#
# - Add genome organism name to table?

# %%
import pandas as pd

# %%
features = pd.DataFrame.from_csv('../features.csv')
genomes = pd.DataFrame.from_csv('../genomes.csv')

clusters = pd.read_csv('../clusters.uc', sep="\t", comment="#", header=None)

clusters = clusters[[0, 1, 8]]

clusters.columns = ['cluster_type', 'cluster', 'feature']
clusters = clusters[clusters['cluster_type'].isin(['H', 'S'])]
clusters = clusters.set_index('feature')

proteins = features.ix[features.type == 'CDS']

# %%
mapping = proteins.join(clusters)[['genome_id', 'cluster']]

print mapping.head()
# group by genome and cluster, count number of features
dat = mapping.groupby(['genome_id', 'cluster']).agg(len).unstack().fillna(0)

# use organisms' names
dat.index = genomes.ix[dat.index]['organism']
dat.head()
# Out:
#        genome_id  cluster
# id
# 62595          2      NaN
# 62598          2     9593
# 62600          2        1
# 62602          2      850
# 62604          2      240
# cluster                          0      1      2      3      4      5      \
# organism
# Bacteroides dorei DSM 17855         21     15      4      5      4      0
# Bacteroides dorei                   16     11      1      6      4      3
# Bacteroides dorei                   10     11      2      2      6      1
# Bacteroides vulgatus ATCC 8482       5     11      2      3      3      1
# Bacteroides vulgatus CL09T03C04     12     11      5      2      6      1
#
# cluster                          6      7      8      9      ...    12215  \
# organism                                                     ...
# Bacteroides dorei DSM 17855          4      0      0      3  ...        0
# Bacteroides dorei                    3      1      1      4  ...        0
# Bacteroides dorei                    2      0      0      5  ...        0
# Bacteroides vulgatus ATCC 8482       1      0      0      1  ...        0
# Bacteroides vulgatus CL09T03C04      2      0      0      1  ...        0
#
# cluster                          12216  12217  12218  12219  12220  12221  \
# organism
# Bacteroides dorei DSM 17855          0      0      0      0      0      0
# Bacteroides dorei                    0      0      0      0      0      0
# Bacteroides dorei                    0      0      0      0      0      0
# Bacteroides vulgatus ATCC 8482       0      0      0      0      0      0
# Bacteroides vulgatus CL09T03C04      0      0      0      0      0      0
#
# cluster                          12222  12223  12224
# organism
# Bacteroides dorei DSM 17855          0      0      0
# Bacteroides dorei                    0      0      0
# Bacteroides dorei                    0      0      0
# Bacteroides vulgatus ATCC 8482       0      0      0
# Bacteroides vulgatus CL09T03C04      0      0      0
#
# [5 rows x 12225 columns]

# %%
# write to table
dat.to_csv('genome-cluster-table.csv')

dat.head()
# Out:
# cluster                          0      1      2      3      4      5      \
# organism
# Bacteroides dorei DSM 17855         21     15      4      5      4      0
# Bacteroides dorei                   16     11      1      6      4      3
# Bacteroides dorei                   10     11      2      2      6      1
# Bacteroides vulgatus ATCC 8482       5     11      2      3      3      1
# Bacteroides vulgatus CL09T03C04     12     11      5      2      6      1
#
# cluster                          6      7      8      9      ...    12215  \
# organism                                                     ...
# Bacteroides dorei DSM 17855          4      0      0      3  ...        0
# Bacteroides dorei                    3      1      1      4  ...        0
# Bacteroides dorei                    2      0      0      5  ...        0
# Bacteroides vulgatus ATCC 8482       1      0      0      1  ...        0
# Bacteroides vulgatus CL09T03C04      2      0      0      1  ...        0
#
# cluster                          12216  12217  12218  12219  12220  12221  \
# organism
# Bacteroides dorei DSM 17855          0      0      0      0      0      0
# Bacteroides dorei                    0      0      0      0      0      0
# Bacteroides dorei                    0      0      0      0      0      0
# Bacteroides vulgatus ATCC 8482       0      0      0      0      0      0
# Bacteroides vulgatus CL09T03C04      0      0      0      0      0      0
#
# cluster                          12222  12223  12224
# organism
# Bacteroides dorei DSM 17855          0      0      0
# Bacteroides dorei                    0      0      0
# Bacteroides dorei                    0      0      0
# Bacteroides vulgatus ATCC 8482       0      0      0
# Bacteroides vulgatus CL09T03C04      0      0      0
#
# [5 rows x 12225 columns]

# %%
# clusters per genome
dat.sum(axis=1).hist()

# %%
# cluster size
ax = fig.add_subplot()
dat.sum(axis=0).hist()

# %%
# "core" genome
core = dat[dat.columns[dat.min(axis=0) > 0]]

# %%
print "found %s core protein families" % len(core.columns)
# Out:
# found 327 core protein families
