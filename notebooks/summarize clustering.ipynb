# %%
import pandas as pd

# %%
dat = pd.read_csv('data/clusters.0.2.uc')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-690d810e52cb> in <module>()
# ----> 1 dat = pd.read_csv('data/clusters.0.2.uc')
#
# ...
